# %%
import pandas as pd

df = pd.read_csv("https://github.com/bsenst/streamlit-llm/raw/main/notebooks/csv/medications.csv")

# %%
df.PATIENT.value_counts()
# Out:
# PATIENT
# 3f336702-bf73-4fc8-bd59-3ba77fd65d0d    3313
# 19d2cfb8-439b-454a-b47e-5274c219005b    1614
# 2c71dd97-7085-416a-aa07-d675bbe3adf2    1563
# cae10920-f977-48b4-a0d3-4d70ad561fd1    1551
# 3acf9313-1874-4dff-ab2a-3187516d92d6    1237
#                                         ...
# 78574ffd-6c17-492a-8bb0-5a0062bb7730       1
# 5072b4ab-5af4-4823-8f25-05d0704dbaec       1
# f4286e97-28cf-4768-99f5-0d1d86295354       1
# 73865a0e-b09d-4604-ad78-f6d2d82f76f8       1
# e3386a13-d652-45fe-abd9-f01d1b023e6f       1
# Name: count, Length: 1107, dtype: int64

# %%
df = df[df.PATIENT=="3f336702-bf73-4fc8-bd59-3ba77fd65d0d"]
df.shape
# Out:
# (3313, 13)

# %%
! pip install sketch -q

# %%
import sketch

# %%
df.columns
# Out:
# Index(['START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE', 'DESCRIPTION',
#        'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')

# %% [markdown]
# # Incomplete results derive illnesses from the medications taken

# %%
df.sketch.ask("from the medication description what diseases does the patient suffer from?")
# Out:
# Based on the REASONDESCRIPTION column, it appears that the patient suffers from Diabetes.

# %%
df.REASONDESCRIPTION.value_counts()
# Out:
# REASONDESCRIPTION
# Anemia (disorder)                 959
# Diabetes                          647
# Viral sinusitis (disorder)          2
# Alzheimer's disease (disorder)      1
# Acute bronchitis (disorder)         1
# Name: count, dtype: int64

# %% [markdown]
# # Identification of the most expensive drug

# %%
df.sketch.ask("what is the most costly drug the patient takes?")
# Out:
# The most costly drug the patient takes is 229763.28, which is associated with the code 198031 and the description "24hr nicotine transdermal patch".

# %%
df.sort_values(by="TOTALCOST").tail(3)
# Out:
#                      START STOP                               PATIENT  \
# 9470  1987-10-16T09:55:43Z  NaN  3f336702-bf73-4fc8-bd59-3ba77fd65d0d
# 9471  1987-10-16T09:55:43Z  NaN  3f336702-bf73-4fc8-bd59-3ba77fd65d0d
# 9353  1948-08-27T09:55:43Z  NaN  3f336702-bf73-4fc8-bd59-3ba77fd65d0d
#
#                                      PAYER  \
# 9470  6e2f1a2d-27bd-3701-8d08-dae202c58632
# 9471  6e2f1a2d-27bd-3701-8d08-dae202c58632
# 9353  6e2f1a2d-27bd-3701-8d08-dae202c58632
#
#                                  ENCOUNTER     CODE  \
# 9470  70e60221-4570-4418-aa55-3be7e31ee074  1860480
# 9471  70e60221-4570-4418-aa55-3be7e31ee074   752899
# 9353  1e8b0348-31c5-42be-8b58-c848bcb89c0c   198031
#
#                                             DESCRIPTION  BASE_COST  \
# 9470                  1 ML DOCEtaxel 20 MG/ML Injection     263.49
# 9471  0.25 ML Leuprolide Acetate 30 MG/ML Prefilled ...     263.49
# 9353                    24hr nicotine transdermal patch     263.49
#
# ...

# %% [markdown]
# # Insufficient information to check for interactions

# %%
df.sketch.ask("considering all unique drug descriptions, can you spot any dangerous interactions?")
# Out:
# No, it is not possible to spot any dangerous interactions from the summary statistics and descriptive data of the dataframe. To identify any potential drug interactions, a more detailed analysis of the data would be required.

# %% [markdown]
# # Incorrect identification of drugs

# %%
df.sketch.ask("which drugs for diabetes does the patient take?")
# Out:
# The patient takes 24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet, as indicated by the DESCRIPTION column which contains the value '24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet'. The REASONCODE column also contains the value '44054006.0', which corresponds to the description 'Diabetes' in the REASONDESCRIPTION column.

# %%
df[df.REASONDESCRIPTION=="Diabetes"].DESCRIPTION.value_counts()
# Out:
# DESCRIPTION
# 24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet                                       325
# insulin human  isophane 70 UNT/ML / Regular Insulin  Human 30 UNT/ML Injectable Suspension [Humulin]    322
# Name: count, dtype: int64

# %%
df.sketch.ask("how many drugs against diabetes does the patient take?")
# Out:
# The patient takes 6 drugs against diabetes, as indicated by the REASONCODE column. The REASONDESCRIPTION column confirms that these drugs are for diabetes.

# %%
df.sketch.ask("is insulin prescribed to the patient?")
# Out:
# The dataframe does not contain information about whether insulin is prescribed to the patient. To answer this question, additional data would need to be collected.
